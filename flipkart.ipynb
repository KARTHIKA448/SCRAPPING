# %%
import pandas as pd

# %%
df = pd.read_csv("flipkart.csv")
df
# Out:
#                                                MOBILE   PRICES  \
# 0                 vivo T2x 5G (Glimmer Black, 128 GB)  ₹14,999
# 1                   vivo T2x 5G (Aurora Gold, 128 GB)  ₹14,999
# 2                   vivo T2x 5G (Marine Blue, 128 GB)  ₹12,999
# 3                   vivo T2x 5G (Aurora Gold, 128 GB)  ₹12,999
# 4                 vivo T2x 5G (Glimmer Black, 128 GB)  ₹12,999
# 5                   vivo T2x 5G (Marine Blue, 128 GB)  ₹11,999
# 6                   vivo T2x 5G (Aurora Gold, 128 GB)  ₹11,999
# 7                 vivo T2x 5G (Glimmer Black, 128 GB)  ₹11,999
# 8                   vivo T2x 5G (Marine Blue, 128 GB)  ₹14,999
# 9           MOTOROLA Edge 40 Neo (Caneel Bay, 256 GB)  ₹24,999
# 10                     REDMI 12C (Matte Black, 64 GB)   ₹7,999
# 11        MOTOROLA Edge 40 Neo (Black Beauty, 256 GB)  ₹24,999
# 12      OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  ₹17,149
# 13                       POCO C55 (Cool Blue, 128 GB)   ₹7,799
# ...

# %%
df.columns
# Out:
# Index(['MOBILE', 'PRICES', 'DESCRIPTION', 'RATINGS & REVIEWS'], dtype='object')

# %%
df.shape
# Out:
# (24, 4)

# %%
df.dtypes
# Out:
# MOBILE                object
# PRICES                object
# DESCRIPTION           object
# RATINGS & REVIEWS    float64
# dtype: object
